# %%
from IPython import display
display.Image("91.png")

# %%
class vehicle:
    
    def __init__(self, name_of_vehicle, max_speed, average_od_vehicle):
        self.name_of_vehicle = name_of_vehicle
        self.max_speed = max_speed
        self.average_od_vehicle = average_od_vehicle

# %%
from IPython import display
display.Image("92.png")

# %%
class vehicle:
    
    def __init__(self, name_of_vehicle, max_speed, average_od_vehicle):
        self.name_of_vehicle = name_of_vehicle
        self.max_speed = max_speed
        self.average_od_vehicle = average_od_vehicle

class  car(vehicle):
    
    def seating_capacity(self, seating_capacity):
        return self.name_of_vehicle , seating_capacity

# %%
c = car("maruti_suzuki", 100, 70)

# %%
c.seating_capacity(5)
# Out:
# ('maruti_suzuki', 5)

# %%
from IPython import display
display.Image("93.png")

# %%
class tea:
    def tea1(self):
        return "i like to have tea in the morning and the evening"
    
class biscuits:
    def bis1(self):
        return "i like to have tea and biscuits"
    
class tea_biscuit(tea, biscuits):
    pass

# %%
o = tea_biscuit()

# %%
#here we can access class tea with the help of creating object of class tea_biscuit
o.tea1()
# Out:
# 'i like to have tea in the morning and the evening'

# %%
#here we can access class biscuit with the help of creating object of class tea_biscuit
o.bis1()
# Out:
# 'i like to have tea and biscuits'

# %%
from IPython import display
display.Image("94.png")

# %% [markdown]
# Ans.Getter: A method that allows you to access an attribute in a given class.
#
# Setter: A method that allows you to set or mutate the value of an attribute in a class.

# %%
class maths:
    def __init__(self,coaching_price,teacher_name):
        self.__coaching_price = coaching_price
        self.teacher_name = teacher_name
        
    @property
    def coaching_price_access(self):
        return self.__coaching_price
    
    @coaching_price_access.setter
    def coaching_price_set(self,price):
        if price <= 3500:
            pass
        else:
            self.__coaching_price = price

# %%
m = maths(2500,"manish bansal")

# %%
m.coaching_price_access
# Out:
# 2500

# %%
m.coaching_price_set = 5000

# %%
m.coaching_price_access
# Out:
# 5000

# %%
from IPython import display
display.Image("95.png")

# %% [markdown]
# Ans. Method overriding is an ability of any object-oriented programming language that allows a subclass or child class to provide a specific implementation of a method that is already provided by one of its super-classes or parent classes. When a method in a subclass has the same name, same parameters or signature and same return type(or sub-type) as a method in its super-class, then the method in the subclass is said to override the method in the super-class.

# %%
class dog:
    
    def show(self):
        return "hey i am a dog"
    
class puppy(dog):
    
    def show(self):
        print("this is a method of overriding")
        return "hey i am a puppy"

# %%
p = puppy()

# %%
p.show()
# Out:
# this is a method of overriding
# 'hey i am a puppy'

# %%
d = dog()

# %%
d.show()
# Out:
# 'hey i am a dog'
