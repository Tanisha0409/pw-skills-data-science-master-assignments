# %%
from IPython import display
display.Image("1.png")

# %%
#read structured data
import pandas as pd
df = pd.read_excel("LUSID Excel - Setting up your market data.xlsx")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
# describe function is used to generate descriptive data set.
df.describe()
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 6
# count         0.0         0.0         0.0         0.0
# mean          NaN         NaN         NaN         NaN
# std           NaN         NaN         NaN         NaN
# min           NaN         NaN         NaN         NaN
# 25%           NaN         NaN         NaN         NaN
# 50%           NaN         NaN         NaN         NaN
# 75%           NaN         NaN         NaN         NaN
# max           NaN         NaN         NaN         NaN

# %%
#nunique function in Pandas is used to get a count of unique values for each column in a DataFrame. It returns a Pandas Series containing the number of unique values for each column in the DataFrame.
df.nunique()
# Out:
# Unnamed: 0     0
# Unnamed: 1     0
# Unnamed: 2     0
# Unnamed: 3     3
# Unnamed: 4    12
# Unnamed: 5     5
# Unnamed: 6     0
# Unnamed: 7     6
# Unnamed: 8     4
# Unnamed: 9     1
# dtype: int64

# %%
# info function - This function is used to print a summary of a DataFrame, including information about the data types, number of non-null values, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  0 non-null      float64
#  2   Unnamed: 2  0 non-null      float64
#  3   Unnamed: 3  3 non-null      object
#  4   Unnamed: 4  12 non-null     object
#  5   Unnamed: 5  7 non-null      object
#  6   Unnamed: 6  0 non-null      float64
#  7   Unnamed: 7  6 non-null      object
#  8   Unnamed: 8  4 non-null      object
#  9   Unnamed: 9  1 non-null      object
# dtypes: float64(4), object(6)
# memory usage: 2.3+ KB

# %%
#head function
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
#tail function
df.tail()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 23         NaN         NaN         NaN        NaN
# 24         NaN         NaN         NaN        NaN
# 25         NaN         NaN         NaN        NaN
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
#
#                                           Unnamed: 4  \
# 23  Although the date can still appears without time
# 24                                               NaN
# 25                      Add an hour to your datetime
# 26                                               NaN
# 27              Subtract a minute from your datetime
#
#                     Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 23  2019-04-10 13:30:45.550000         NaN        NaN        NaN        NaN
# 24                         NaN         NaN        NaN        NaN        NaN
# 25  2019-04-10 14:30:45.550000         NaN        NaN        NaN        NaN
# ...

# %%
from IPython import display
display.Image("2.png")

# %%
# Creating a custom function for generating the dataframe as mentioned above
def reindex_dataframe(df):
    new_index = range(1, len(df)+1, 2) # create new index starting from 1 and incrementing by 2
    df = df.reindex(new_index) # re-index the DataFrame with the new index
    return df

# %%
# create sample DataFrame
df = pd.DataFrame({'A': ['T', 'V', 'I', 'A','S','R'], 'B': [True, False,True, True, True, False], 'C': [1, 2, 3, 4, 5, 6]})

# Showing orignal DataFrame
df
# Out:
#    A      B  C
# 0  T   True  1
# 1  V  False  2
# 2  I   True  3
# 3  A   True  4
# 4  S   True  5
# 5  R  False  6

# %%
# re-index the DataFrame
df_reindexed = reindex_dataframe(df)

# print the re-indexed DataFrame
df_reindexed
# Out:
#    A      B  C
# 1  V  False  2
# 3  A   True  4
# 5  R  False  6

# %%
from IPython import display
display.Image("3.png")

# %%
def sum_first_three_values(df):
    values = df['Values'].values # get the 'Values' column as a NumPy array
    sum_of_first_three = sum(values[:3]) # calculate the sum of the first three values
    print(f"The sum of the first three values is {sum_of_first_three}")

# %%
#sample data frame
df = pd.DataFrame({'Values' : [10, 20, 30, 40, 50]})
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
#sum of first three values
sum_first_three_values(df)
# Out:
# The sum of the first three values is 60

# %%
from IPython import display
display.Image("4.png")

# %%
import pandas as pd
def add_word_count_column(df):
    #define a function to count the no.s of word in a string
    def count_word(text):
        return len(text.split())
    #applying the count_word function to the 'text' column of the dataframe
    df['word_count'] = df['text'].apply(count_word)
    
    return df

# %%
df = pd.DataFrame({'text': ['my name is tanisha kumari khaitan', 'i am pursuing data science course', 'i have completed my graduation and taken addmission in masters']})

# %%
df
# Out:
#                                                 text
# 0                  my name is tanisha kumari khaitan
# 1                  i am pursuing data science course
# 2  i have completed my graduation and taken addmi...

# %%
add_word_count_column(df)
# Out:
#                                                 text  word_count
# 0                  my name is tanisha kumari khaitan           6
# 1                  i am pursuing data science course           6
# 2  i have completed my graduation and taken addmi...          10

# %%
from IPython import display
display.Image("5.png")

# %% [markdown]
# Ans. Both DataFrame.size and DataFrame.shape are attributes of a Pandas DataFrame, but they return different values.
#
# 1. DataFrame.size returns the total number of elements in the DataFrame, which is the product of the number of rows and columns. It is equivalent to the size of the underlying NumPy array.
#
# 2. DataFrame.shape returns a tuple containing the number of rows and columns in the DataFrame, respectively. It is a convenient way to check the dimensions of the DataFrame.
#
# Here's an example that demonstrates the difference between DataFrame.size and DataFrame.shape:

# %%
#create a dataframe of 2 rows and 3 columns
df = pd.DataFrame({'name': ['tanisha', 'vivek'], 'age': [22, 27], 'dream': ['data scientist', 'ias officer']})

#printing datashape and datasize of the dataframes
print("data shape of data frame: ", df.shape)
print("data size of data frame: ", df.size)
# Out:
# data shape of data frame:  (2, 3)
# data size of data frame:  6

# %%
from IPython import display
display.Image("6.png")

# %% [markdown]
# To read an Excel file in Pandas, we can use the read_excel() function. This function is part of the Pandas IO tools and can read data from Excel files with various extensions like .xlsx, .xls, and .xlsm.

# %%
#read structured data
import pandas as pd
df = pd.read_excel("LUSID Excel - Setting up your market data.xlsx")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
from IPython import display
display.Image("7.png")

# %%
def add_username_column(df):
    #define a function that splits the string at @ character and return a string i.e only username
    
    def username(email):
        return email.split('@')[0]
    
    # apply the username function to the 'email' column of the DataFrame
    df['username'] = df['email'].apply(username)

    
    return df

# %%
df = pd.DataFrame({'email': ['tanishakhaitan@gmail.com', 'vivekranjan@gmail.com', 'ramankumar@gmail.com', 'shiprasingh@gmail.com', 'lovelykumari@gmail.com']})
df
# Out:
#                       email
# 0  tanishakhaitan@gmail.com
# 1     vivekranjan@gmail.com
# 2      ramankumar@gmail.com
# 3     shiprasingh@gmail.com
# 4    lovelykumari@gmail.com

# %%
add_username_column(df)
# Out:
#                       email        username
# 0  tanishakhaitan@gmail.com  tanishakhaitan
# 1     vivekranjan@gmail.com     vivekranjan
# 2      ramankumar@gmail.com      ramankumar
# 3     shiprasingh@gmail.com     shiprasingh
# 4    lovelykumari@gmail.com    lovelykumari

# %%
from IPython import display
display.Image("8.png")

# %%
df = pd.DataFrame ({'A': [3, 8, 6, 2, 9], 'B': [5, 2, 9, 3, 1], 'C': [1, 7, 4, 5, 2]})
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
df[(df['A'] > 5) & (df['B'] < 10)]
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %%
from IPython import display
display.Image("81.png")

# %%
from IPython import display
display.Image("9.png")

# %%
def calculate_stats(df):
    #calculating mean, median , standard deviation
    mean = df['values'].mean()
    median = df['values'].median()
    stdev = df['values'].std()
    
    
    return mean ,median ,stdev

# %%
#creating data frame
df = pd.DataFrame({'values': [11, 5, 6, 2, 12, 9, 4, 19, 27, 29, 10, 8, 26]})
df
# Out:
#     values
# 0       11
# 1        5
# 2        6
# 3        2
# 4       12
# 5        9
# 6        4
# 7       19
# 8       27
# 9       29
# 10      10
# 11       8
# 12      26

# %%
#printing mean, median, std
mean, median , stdev = calculate_stats(df)
print(f'Mean of Values is : {mean}')
print(f'Median of Values is : {median}')
print(f'Standard Deviation of Values is : {stdev}')
# Out:
# Mean of Values is : 12.923076923076923
# Median of Values is : 10.0
# Standard Deviation of Values is : 9.250779592927456

# %%
from IPython import display
display.Image("10.png")

# %%
import pandas as pd

def calculate_moving_average(df):
    # sort the DataFrame by date
    df = df.sort_values(by='Date')

    # calculate the moving average using a rolling window of size 7
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()

    return df

# %%
df = pd.DataFrame({
    'Date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08', '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12'],
    'Sales': [11, 15, 35, 41, 42, 64, 72, 51, 65, 81, 95, 111]
})

df = calculate_moving_average(df)

# %%
df_new = calculate_moving_average(df)
df_new
# Out:
#           Date  Sales  MovingAverage
# 0   2022-01-01     11      11.000000
# 1   2022-01-02     15      13.000000
# 2   2022-01-03     35      20.333333
# 3   2022-01-04     41      25.500000
# 4   2022-01-05     42      28.800000
# 5   2022-01-06     64      34.666667
# 6   2022-01-07     72      40.000000
# 7   2022-01-08     51      45.714286
# 8   2022-01-09     65      52.857143
# 9   2022-01-10     81      59.428571
# 10  2022-01-11     95      67.142857
# 11  2022-01-12    111      77.000000

# %%
from IPython import display
display.Image("11.png")

# %%
from IPython import display
display.Image("111.png")

# %%
#here i am assuming that dates are given in string format
def return_weekdays(df):

    # Below changes String Date to datetime format
    df['Date']=pd.to_datetime(df['Date'])

    # below returns weekdays returns weekday
    df['Weekday'] = df['Date'].dt.day_name()
    return df

# %%
df = pd.DataFrame({'Date':['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05']})
df
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
df_new = return_weekdays(df)
df_new
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %%
from IPython import display
display.Image("12.png")

# %%
def select_january_rows(df):
    #convert 'date' column to pandas datetime format
    df['date'] = pd.to_datetime(df['date'])
    
    
    #select rows with date '2023-01-01' and '2023-01-31'
    january_rows = df[df['date'].between ('2023-01-01', '2023-01-31')]
    
    return january_rows

# %%
df = pd.DataFrame({'date':pd.date_range(start='12/1/2022',end='3/1/2023',freq='D')})
df
# Out:
#          date
# 0  2022-12-01
# 1  2022-12-02
# 2  2022-12-03
# 3  2022-12-04
# 4  2022-12-05
# ..        ...
# 86 2023-02-25
# 87 2023-02-26
# 88 2023-02-27
# 89 2023-02-28
# 90 2023-03-01
#
# [91 rows x 1 columns]

# %%
select_january_rows(df)
# Out:
#          date
# 31 2023-01-01
# 32 2023-01-02
# 33 2023-01-03
# 34 2023-01-04
# 35 2023-01-05
# 36 2023-01-06
# 37 2023-01-07
# 38 2023-01-08
# 39 2023-01-09
# 40 2023-01-10
# 41 2023-01-11
# 42 2023-01-12
# 43 2023-01-13
# 44 2023-01-14
# 45 2023-01-15
# 46 2023-01-16
# 47 2023-01-17
# 48 2023-01-18
# 49 2023-01-19
# 50 2023-01-20
# 51 2023-01-21
# 52 2023-01-22
# 53 2023-01-23
# 54 2023-01-24
# 55 2023-01-25
# 56 2023-01-26
# 57 2023-01-27
# 58 2023-01-28
# 59 2023-01-29
# 60 2023-01-30
# 61 2023-01-31

# %%
from IPython import display
display.Image("13.png")

# %%
#basic function of pandas , pandas itself is the first and foremost necessary library that needs to be imported
import pandas as pd
