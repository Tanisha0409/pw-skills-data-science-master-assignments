# %%
from IPython import display
display.Image("1.png")

# %% [markdown]
# Ans. open() function
# The open() function opens the file specified by filename and associates a stream with it. The mode variable is a character string specifying the type of access requested for the file.Syntax: open(filename, mode)
#
#
# Here the mode refers to the Access Mode. Access modes govern the type of operations possible in the opened file. It refers to how the file will be used once it’s opened. These modes also define the location of the File Handle in the file. File handle is like a cursor, which defines from where the data has to be read or written in the file. There are 6 access modes in python.
#
# 1. Read Only (‘r’): Open text file for reading. The handle is positioned at the beginning of the file. If the file does not exists, raises I/O error. This is also the default mode in which file is opened.
# 2. Read and Write (‘r+’): Open the file for reading and writing. The handle is positioned at the beginning of the file. Raises I/O error if the file does not exists.
# 3. Write Only (‘w’): Open the file for writing. For existing file, the data is truncated and over-written. The handle is positioned at the beginning of the file. Creates the file if the file does not exists.
# 4. Write and Read (‘w+’): Open the file for reading and writing. For existing file, data is truncated and over-written. The handle is positioned at the beginning of the file.
# 5. Append Only (‘a’): Open the file for writing. The file is created if it does not exist. The handle is positioned at the end of the file. The data being written will be inserted at the end, after the existing data.
# 6. Append and Read (‘a+’): Open the file for reading and writing. The file is created if it does not exist. The handle is positioned at the end of the file. The data being written will be inserted at the end, after the existing data.

# %%
#open a file
f = open("file.txt", 'w')
f.write("this is my first file to create"+"/n")
f.close()

# %%
# 'r' read mode
f = open("file.txt", 'r')
text = f.read()
print(text)
f.close()
# Out:
# this is my first file to create/n

# %%
#'w' write mode
f = open("file.txt", 'w')
f.write("this is my write mode in file"+"/n")
f.close()

# %%
#r+ read and write mode
f = open("file.txt",'r+')
data = f.read()
f.write("this is my read pluse write mode in file"+"/n")
print(data)
f.close()
# Out:
# this is my write mode in file/n

# %%
#w+ reading  and writing
f = open('file.txt', 'w+')
lines = f.read()
f.write('This is w+ my mode in file')
f.close()

# %%
#a append 
f = open('file.txt', 'a')
a = 'This is my text written in append mode in file'+"/n"
f.write(a)
f.close()

# %%
#a+ appending and writing
f = open('file.txt', 'a+')
a = f.read()
f.write('This is  my append pluse writing mode in file')
f.close()

# %%
from IPython import display
display.Image("2.png")

# %% [markdown]
# Ans. close() is used  to close an open file when the user has done his file. It is always a good practice to close a file after performing desired operations to it. Thus makes sure that all our changes have been saved to the file. Example:

# %%
f = open("file.txt", 'r')
text = f.read()
print(text)

f.close()
# Out:
# This is w+ my mode in fileThis is my text written in append mode in file/nThis is  my append pluse writing mode in file

# %%
from IPython import display
display.Image("3.png")

# %%
#opening a file name file1
f = open("file1.txt", 'w')
f.write("i want to become a data scientist")
f.close()

# %%
#reading a file name file1
f = open("file1.txt", 'r')
text = f.read()
print(text)
f.close()
# Out:
# i want to become a data scientist

# %%
from IPython import display
display.Image("4.png")

# %% [markdown]
# Ans. 1. The read() method returns the specified number of bytes from the file. Default is -1 which means the whole file.

# %%
#read()
f = open("file.txt", 'r')
text = f.read(8)
print(text)
f.close()
# Out:
# This is

# %% [markdown]
# 2. The readline() method returns one line from the file. You can also specified how many bytes from the line to return, by using the size parameter.

# %%
#readline()
f = open("file.txt", 'r')
text = f.readline()
print(text)
f.close()
# Out:
# This is w+ my mode in fileThis is my text written in append mode in file/nThis is  my append pluse writing mode in file

# %% [markdown]
# 3. The readlines() method returns a list containing each line in the file as a list item.

# %%
#readlines()
f = open("file.txt", 'r')
text = f.readlines()
print(text)
f.close()
# Out:
# ['This is w+ my mode in fileThis is my text written in append mode in file/nThis is  my append pluse writing mode in file']

# %%
from IPython import display
display.Image("5.png")

# %% [markdown]
# Ans. In Python, with statement is used in exception handling to make the code cleaner and much more readable. It simplifies the management of common resources like file streams.
#
# Advantage : unlike the previous implementations, there is no need to call file.close()
#
# It is guaranteed to close the file no matter how the nested block exits. If an exception occurs before the end of the block, it will close the file before the exception is caught by an outer exception handler.

# %%
with open("file.txt", 'w') as f:
    f.write("this is my file")
    f.close()

# %%
with open("file.txt", 'r') as f:
    print(f.read())
# Out:
# this is my file

# %%
from IPython import display
display.Image("6.png")

# %% [markdown]
# Ans. 1. The write() function will write the content in the file without adding any extra characters.
#  While writing data to a file, we must know that the write function does not add a newline character(\n) to the end of the string.<
#  The write() function returns None.

# %%
# write()
file = open("Employees.txt", "w")
l = ["tanisha", "samyak", "isha"]  
for i in l:
   
   file.write(f"name :{i} ")
   file.write("\n")
     
file.close()
  
print("Data is written into the file.")
# Out:
# Data is written into the file.

# %%
file = open("Employees.txt", "r")
print(file.read())
# Out:
# name :tanisha
# name :samyak
# name :isha

# %% [markdown]
# 2. writelines(): This function writes the content of a list to a file.
# the list of strings that is passed to the writelines() function is written into the opened file.
# Similar to the write() function, the writelines() function does not add a newline character(\n) to the end of the string

# %%
# writeline()
file1 = open("Employees.txt", "w")
lst = []
for i in range(3):
    name = input("Enter the name of the employee: ")
    lst.append(name + '\n')
      
file1.writelines(lst)
file1.close()
print("Data is written into the file.")

# %%
file1 = open("Employees.txt", "r")
print(file1.read())
# Out:
# aman
# sony
# shalini
